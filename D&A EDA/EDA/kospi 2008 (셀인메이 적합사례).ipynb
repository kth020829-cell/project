# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm 
fm.fontManager.ttflist
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['STIXGeneral',
#  'cmss10',
#  'STIXSizeThreeSym',
#  'cmmi10',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'cmex10',
#  'DejaVu Sans Display',
#  'DejaVu Serif',
#  'STIXSizeOneSym',
#  'cmsy10',
#  'STIXSizeFourSym',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'STIXSizeFiveSym',
#  'DejaVu Sans Mono',
#  'cmr10',
#  'DejaVu Serif Display',
#  'DejaVu Sans',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'cmtt10',
#  'STIXSizeThreeSym',
#  'STIXSizeTwoSym',
#  'cmb10',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'Book Antiqua',
#  'Lucida Handwriting',
#  'Comic Sans MS',
#  'Onyx',
#  'Haettenschweiler',
#  'GyeonggiBatang',
#  'Goudy Old Style',
#  'GyeonggiBatang',
#  'Microsoft PhagsPa',
#  'HCR Dotum Ext',
#  'HYMyeongJo-Extra',
#  'Microsoft New Tai Lue',
# ...

# %%
#데이터불러오기
data = pd.read_csv(r"C:\Users\touch\OneDrive\바탕 화면\코스피_주요주가지수_20240516103642.csv", encoding='utf-8')
data
# Out:
#                지수종류별(1)   지수종류별(2)  2008.01  2008.02  2008.03  2008.04  \
# 0                 KOSPI         소계  1624.68  1711.62  1703.99  1825.47
# 1             KOSPI 200         소계   207.77   216.85   217.65   235.00
# 2           V-KOSPI 200         소계    31.39    29.21    27.05    22.04
# 3             KOSPI 100         소계  1532.82  1589.24  1595.55  1727.82
# 4              KOSPI 50         소계  1382.74  1416.32  1426.65  1549.27
# 5               시가총액규모별        대형주  1577.27  1644.04  1657.05  1780.91
# 6               시가총액규모별        중형주  2069.13  2279.39  2142.36  2271.29
# 7               시가총액규모별        소형주  1207.73  1308.68  1245.07  1273.06
# 8           F-KOSPI 200         소계  1076.35  1122.94  1121.11  1221.06
# 9     F-KOSPI 200 인버스지수         소계     0.00     0.00     0.00     0.00
# 10     KOSPI 200 레버리지지수         소계     0.00     0.00     0.00     0.00
# 11    KOSPI 200 커버드콜 지수         소계   200.81   211.42   210.96   223.15
# ...

# %%
df = data.iloc[0, 2:]
df
# Out:
# 2008.01    1624.68
# 2008.02    1711.62
# 2008.03    1703.99
# 2008.04    1825.47
# 2008.05    1852.02
# 2008.06    1674.92
# 2008.07    1594.67
# 2008.08    1474.24
# 2008.09    1448.06
# 2008.10    1113.06
# 2008.11    1076.07
# 2008.12    1124.47
# 2009.01    1162.11
# 2009.02    1063.03
# 2009.03    1206.26
# 2009.04    1369.36
# Name: 0, dtype: object

# %%
#결측치 확인
df.isnull().sum()
# Out:
# 0

# %%
plt.rcParams['font.family'] = 'NanumGothic'

plt.plot(df.values, marker = 'o', color = 'g', label = '2008.01 - 2009.04')

plt.title('KOSPI 2008',fontdict={'size':20})
plt.xlabel('월', loc = 'right')
plt.ylabel('변동지수', loc = 'top')
plt.xticks(ticks = [i for i in range(0,16)], labels = [i for i in range(1,13)] + [1,2,3,4])
plt.legend(loc = 'upper right')

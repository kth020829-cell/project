# %% [markdown]
# # 머신러닝 기초Ⅱ

# %%
import pandas as pd
import numpy as np

iris = pd.read_csv('Iris.csv')
adv = pd.read_csv('advertising.csv')

# %% [markdown]
# ## 01. 분류와 회귀

# %% [markdown]
# ### 분류
# 다음은 iris 꽃에 대한 dataset이다.
# `Species`을 target값으로 하는, 즉, 꽃의 종류를 종속변수 y로 하는 분류문제에 해당한다.
#
#
#
# - `Id` : 일련번호
# - `SepalLengthCm` : 꽃받침 길이 (cm)
# - `SepalWidthCm` : 꽃받침 넓이 (cm)
# - `PetalLengthCm` : 꽃잎 길이 (cm)
# - `PetalWidthCm` : 꽃잎 넓이 (cm)
# - `Species` : 꽃 종류 (setosa, versicolor, virginica)
#
# 꽃의 종류가 3가지이므로 다중분류 문제에 해당한다.

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### 회귀
# 다음은 광고와 판매에 대한 dataset이다.
# `Sales`를 target값으로 하는, 즉, 판매량을 종속변수 y로 하는 회귀문제에 해당한다.
#
# - `TV` : TV 광고량
# - `Radio` : 라디오 광고량
# - `Newspaper` : 신문 광고량
# - `Sales` : 총 판매량
#
# Sales가 연속적인 값이기에 회귀 문제에 해당한다.

# %%
adv.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %% [markdown]
# ## 02. 교차검증

# %%
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold, LeaveOneOut
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Hold-Out Cross Validation
# 데이터셋을 train set, validation set, test set 세 개로 나누어 train set으로 모델을 훈련시키고, validation set으로 성능을 평가한 후, test set을 이용하여 모델의 일반화 성능을 추정하는 교차 검증 방법

# %%
X = iris.iloc[:,1:-1] # 'Id'를 제외한 feature 사용
y = iris['Species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2)
    
print('Train 데이터 비율 : {}'.format(len(X_train)/len(X)))
print('Validation 데이터 비율 : {}'.format(len(X_val)/len(X)))
print('Test 데이터 비율 : {}'.format(len(X_test)/len(X)))
# Out:
# Train 데이터 비율 : 0.64
# Validation 데이터 비율 : 0.16
# Test 데이터 비율 : 0.2

# %% [markdown]
# ### K-Fold Cross Validation
# 데이터셋을 K개로 나누어 하나씩 test set으로 사용하고 나머지를 trian set으로 사용하는 교차검증 방법

# %%
iris.Species.value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
kfold_iris = KFold(n_splits=3) # 3개의 폴드로 나눔
cnt_iter = 0 
for train_idx, test_idx in kfold_iris.split(iris): # 2개의 훈련폴드, 1개의 테스트 폴드로 나누기 위한 인덱스 생성
    cnt_iter += 1
    label_train = iris['Species'].iloc[train_idx]
    label_test = iris['Species'].iloc[test_idx]
    
    print('** 교차검증: {} **'.format(cnt_iter))
    print('학습 레이블 데이터 분포 : \n' , label_train.value_counts())
    print('검증 레이블 데이터 분포 : \n' , label_test.value_counts())
    print('\n')
# Out:
# ** 교차검증: 1 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    50
# Name: count, dtype: int64
#
#
# ** 교차검증: 2 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa       50
# Iris-virginica    50
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Name: count, dtype: int64
#
#
# ** 교차검증: 3 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    50
# Name: count, dtype: int64

# %% [markdown]
# ### Stratified K-Fold Cross Validation
# target 속성값의 개수를 동일하게 하여 데이터가 한 곳으로 몰리는 것을 방지하는 교차검증방법
#
# iris data는 target값이 setosa, versicolor, virginica로 나뉘는데 위 결과를 보면
# - 교차검증 1 : versicolor와 virginica만 학습하여 setosa라는 답을 도출할 수 없다.
# - 교차검증 2 : setosa와 virginica만 학습하여 versicolor라는 답을 도출할 수 없다.
# - 교차검증 3 : setosa와 versicolor만 학습하여 virginica라는 답을 도출할 수 없다.
#
#
#
# 따라서 이러한 K-fold의 문제점을 보완하기 위해 나오게 되었다.

# %%
kfold_iris = StratifiedKFold(n_splits=3)
cnt_iter = 0 
for train_idx, test_idx in kfold_iris.split(iris, iris['Species']): 
    #iris['Species']가 들어가면서 훈련세트와 테스트세트에 종의 비율이 동일하도록 데이터 분할
    cnt_iter += 1
    label_train = iris['Species'].iloc[train_idx]
    label_test = iris['Species'].iloc[test_idx]
    
    print('** 교차검증: {} **'.format(cnt_iter))
    print('학습 레이블 데이터 분포 : \n' , label_train.value_counts())
    print('검증 레이블 데이터 분포 : \n' , label_test.value_counts())
    print('\n')
# Out:
# ** 교차검증: 1 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-virginica     34
# Iris-setosa        33
# Iris-versicolor    33
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa        17
# Iris-versicolor    17
# Iris-virginica     16
# Name: count, dtype: int64
#
#
# ** 교차검증: 2 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    34
# Iris-setosa        33
# Iris-virginica     33
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa        17
# Iris-virginica     17
# Iris-versicolor    16
# Name: count, dtype: int64
#
#
# ** 교차검증: 3 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        34
# Iris-versicolor    33
# Iris-virginica     33
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    17
# Iris-virginica     17
# Iris-setosa        16
# Name: count, dtype: int64

# %% [markdown]
# ### cross_val_score
# sklearn은 k-fold 교차검증을 편리하게 수행할 수 있는 API인 cross_val_score라는 함수를 제공
#
# - 폴드 세트를 지정하고, for 루프에서 반복으로 학습 및 테스트 데이터의 인덱스를 추출한 후, 반복적으로 학습과 예측을 수행하는 일련의 과정을 한 번에 수행해 주는 API
# - 분류의 경우 기본적으로 Stratifies KFold 방식을 사용하여, 각 폴드에서 클래스의 비율이 유지되도록 한다.
#
# - 사용법 : cross_val_score (estimator, X, y, scoring = 평가지표, cv = 교차검증 폴드 수)

# %%
model = DecisionTreeClassifier()
scores = cross_val_score(model, X, y, scoring = 'accuracy', cv = 3) #모델,피처,레이블,평가지표,교차검증폴드수
print('교차 검증별 정확도 :', np.round(scores, 4))
print('교차 검증 평균 :', np.round(np.mean(scores), 4))
# Out:
# 교차 검증별 정확도 : [0.98 0.94 0.98]
# 교차 검증 평균 : 0.9667

# %% [markdown]
# ### Leave-One-Out Cross Validation
# 교차검증의 극단적인 형태로, n개의 데이터 샘플이 있을 때 각 샘플을 한 번씩 테스트 세트로 사용하고 나머지 n-1개의 샘플을 훈련 세트로 사용하는 방법
# == 데이터 수가 150개이면 1개씩 테스트 세트로, 149개를 훈련세트로 사용 == 150개의 교차검증 수행
# - 데이터셋의 각 샘플이 테스트 세트로 선택되는 n개의 교차 검증을 수행한다.

# %%
loo_iris = LeaveOneOut()
cnt_iter = 0 
for train_idx, test_idx in loo_iris.split(iris):
    cnt_iter += 1
    label_train = iris['Species'].iloc[train_idx]
    label_test = iris['Species'].iloc[test_idx]
    
    print('** 교차검증: {} **'.format(cnt_iter))
    print('학습 레이블 데이터 분포 : \n' , label_train.value_counts())
    print('검증 레이블 데이터 분포 : \n' , label_test.value_counts())
    print('\n')
    
print(f'Total number of cross-validation iterations: {cnt_iter}')
# Out:
# ** 교차검증: 1 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 2 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 3 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 4 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 5 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 6 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 7 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 8 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 9 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 10 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 11 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 12 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 13 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 14 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 15 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 16 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 17 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 18 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 19 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 20 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 21 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 22 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 23 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 24 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 25 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 26 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 27 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 28 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 29 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 30 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 31 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 32 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 33 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 34 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 35 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 36 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 37 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 38 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 39 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 40 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 41 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 42 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 43 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 44 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 45 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 46 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 47 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 48 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 49 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 50 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-setosa    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 51 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 52 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 53 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 54 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 55 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 56 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 57 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 58 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 59 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 60 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 61 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 62 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 63 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 64 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 65 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 66 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 67 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 68 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 69 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 70 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 71 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 72 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 73 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 74 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 75 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 76 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 77 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 78 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 79 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 80 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 81 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 82 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 83 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 84 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 85 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 86 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 87 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 88 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 89 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 90 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 91 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 92 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 93 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 94 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 95 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 96 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 97 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 98 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 99 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 100 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-versicolor    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 101 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 102 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 103 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 104 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 105 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 106 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 107 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 108 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 109 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 110 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 111 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 112 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
# ** 교차검증: 113 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 114 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 115 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 116 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 117 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 118 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 119 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 120 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 121 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 122 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 123 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 124 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 125 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 126 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 127 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 128 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 129 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 130 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 131 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 132 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 133 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 134 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 135 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 136 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 137 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 138 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 139 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 140 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 141 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 142 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 143 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 144 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 145 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 146 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 147 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 148 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 149 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# ** 교차검증: 150 **
# 학습 레이블 데이터 분포 :
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     49
# Name: count, dtype: int64
# 검증 레이블 데이터 분포 :
#  Species
# Iris-virginica    1
# Name: count, dtype: int64
#
#
# Total number of cross-validation iterations: 150

# %% [markdown]
# ## 03. 회귀 평가지표
# 실제값과 예측값의 차이가 작을 수록 모델의 성능이 좋다는 것을 의미한다.

# %%
X = adv.iloc[:,:-1]
y = adv['Sales']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = DecisionTreeRegressor()
model.fit(X_train, y_train)
pred = model.predict(X_test)

# %% [markdown]
# ### MSE & RMSE
# #### - MSE (평균 제곱 오차)
#     : 실제값과 예측값의 차이를 제곱하여 평균한 것
#
#
# #### - RMSE (평균 제곱근 오차)
#     : MSE에 루트를 씌운 것

# %%
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test, pred)
RMSE = np.sqrt(MSE)

print('MSE :', MSE)
print('RMSE :', RMSE)
# Out:
# MSE : 2.7392499999999997
# RMSE : 1.655067974434887

# %% [markdown]
# ### MAE(평균 절대 오차)
#     : 실제값과 예측값의 차이를 절댓값으로 변환해 평균한 것

# %%
from sklearn.metrics import mean_absolute_error

MAE = mean_absolute_error(y_test, pred)

print('MAE :', MAE)
# Out:
# MAE : 1.1275

# %% [markdown]
# ### MAPE (평균 절대 비율 오차)
#     : MAE를 비율(％)로 표현한 것

# %%
def MAPE(y_test, y_pred):
    return np.mean(np.abs((y_test - y_pred) / y_test)) * 100
    
mape = MAPE(y_test, pred)

print('MAPE :', mape)
# Out:
# MAPE : 15.603645334561037

# %% [markdown]
# ## 04. 분류 평가지표
# 실제값과 예측값이 일치하는 수가 많을수록 모델의 성능이 좋다는 것을 의미한다.

# %% [markdown]
# ### Confusion Matrix(오차행렬)
#
# <img align="left" src="https://velog.velcdn.com/images%2Fsset2323%2Fpost%2F2fb704cf-8556-40fc-87a2-75b8feb32986%2Fimage.png" width=500 height=300>

# %%
iris = iris[iris['Species'] != "Iris-virginica"] # Iris 데이터셋에서 'Iris-virginica'를 제외하고 이진 분류 문제로 단순화

X = iris.iloc[:,:-1]
y = iris['Species']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

model = DecisionTreeClassifier(max_depth=1, max_features=1, max_leaf_nodes=2, random_state=1)
model.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, pred)
print(cm)
# Out:
# [[ 2  6]
#  [ 0 12]]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["setosa", "versicolor"])
disp.plot(cmap=plt.cm.Blues)

plt.show()

# %%
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel() # ravel(): 다차원 배열을 1차원 배열로 펼치는(pivoting) 메서드
print('tn, fp, fn, tp :', tn, fp, fn, tp)
# Out:
# tn, fp, fn, tp : 2 6 0 12

# %% [markdown]
# ### Accuracy(정확도)
#     : 전체 데이터 중, 정확하게 예측한 데이터의 비율
#     TP+TN / TP+FN+FP+TN

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, pred)

print('Accuracy :', accuracy)
# Out:
# Accuracy : 0.7

# %% [markdown]
# ### Specificity(특이도)
#     : Negative로 예측한 것 중, 진짜 Negative의 비율 (실제 Negative 중, 진짜 Negative의 비율?)
#     TN / TN+FP

# %%
specificity = tn/(tn + fp)

print('Specificity :', specificity)
# Out:
# Specificity : 0.25

# %% [markdown]
# ### Precision(정밀도)
#     : Positive로 예측한 것 중, 진짜 Positive의 비율
#     TP / TP+FP

# %%
from sklearn.metrics import precision_score

precision = precision_score(y_test, pred, pos_label = 'Iris-versicolor')

print('Precision :', precision)
# Out:
# Precision : 0.6666666666666666

# %% [markdown]
# ### Recall(재현율) = Sensitivity(민감도)
#     : 진짜 positive인 것 중, 올바르게 Positive로 예측한 비율
#     TP / TP+FN

# %%
from sklearn.metrics import recall_score

recall = recall_score(y_test, pred, pos_label = 'Iris-versicolor')
# pos_label로 양성클래스 지정

print('Recall :', recall)
# Out:
# Recall : 1.0

# %% [markdown]
# ### F1-Score
#     : Precision과 Recall을 이용하여 조화평균을 구한 지표,
#     정밀도와 재현율이 어느 한쪽으로 치우치지 않을 때 높은 값
#     2 * (recall*precision/recall+precision)

# %%
from sklearn.metrics import f1_score

f1 = f1_score(y_test, pred, pos_label = 'Iris-versicolor')

print('F1 Score :', f1)
# Out:
# F1 Score : 0.8

# %% [markdown]
# ### ROC-AUC
#     : FPR (False Positive Rate)와 TPR (True Positive Rate, 즉 Recall) 사이의 관계를 시각화한 곡선
#     : ROC curve의 밑부분 면적인 AUC가 넓을수록 모델 성능이 높아지는 것을 의미한다.
#
# - FPR : 실제 Negative인 샘플 중에서 Positive로 잘못 예측한 비율. FPR = FP / (FP + TN)
# - TPR : 실제 Positive인 샘플 중에서 Positive로 올바르게 예측한 비율. TPR = TP / (TP + FN)
#
# <img src='https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F262E8E3F544837AD27'>

# %% [markdown]
# #### ROC curve

# %%
from sklearn.metrics import RocCurveDisplay

roc_display = RocCurveDisplay.from_estimator(model, X_test, y_test)

plt.title('ROC curve')
plt.show()

# %%
model.predict_proba(X_test) # setosa일 확률, versicolor일 확률
# Out:
# array([[0.2745098 , 0.7254902 ],
#        [0.2745098 , 0.7254902 ],
#        [0.96551724, 0.03448276],
#        [0.2745098 , 0.7254902 ],
#        [0.2745098 , 0.7254902 ],
#        [0.2745098 , 0.7254902 ],
#        [0.2745098 , 0.7254902 ],
#        [0.2745098 , 0.7254902 ],
#        [0.2745098 , 0.7254902 ],
#        [0.96551724, 0.03448276],
#        [0.2745098 , 0.7254902 ],
#        [0.2745098 , 0.7254902 ],
#        [0.2745098 , 0.7254902 ],
#        [0.2745098 , 0.7254902 ],
#        [0.2745098 , 0.7254902 ],
#        [0.2745098 , 0.7254902 ],
#        [0.2745098 , 0.7254902 ],
#        [0.2745098 , 0.7254902 ],
#        [0.2745098 , 0.7254902 ],
#        [0.2745098 , 0.7254902 ]])

# %%
model.predict(X_test)
# Out:
# array(['Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor'], dtype=object)

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

ROC_AUC = roc_auc_score(y_test, model.predict_proba(X_test)[:,1]) # AUC  
print('ROC_AUC_score :', ROC_AUC)

fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:,1], pos_label='Iris-versicolor')
# roc_curve는 TPR, FPR, 임계값 이렇게 세가지 값을 반환
print('AUC: ', auc(fpr, tpr)) # auc = ROC 곡선의 아래 면적 계산

# roc_auc_score와 auc는 똑같은 값을 반환하지만, 
# roc_auc_score는 실제 레이블(y_test)과 예측 확률(model.predict_proba(X_test)[:,1])을 인자로 받고, 
# auc는 인자로 fpr, tpr을 받는다.
# Out:
# ROC_AUC_score : 0.625
# AUC:  0.625
